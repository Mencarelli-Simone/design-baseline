# %%
from spherical_earth_geometry_radar import mesh_doppler_to_azimuth
import numpy as np

# %%
wave = 3e8/10e9
v_s = 7.2e3
theta = 30
doppler_mesh = np.linspace(-900e3,900e3,1000)
theta_mesh = np.ones_like(doppler_mesh)*theta * np.pi/180
th, A, Tk = mesh_doppler_to_azimuth(theta_mesh, doppler_mesh,wave, v_s)

# %%
import matplotlib.pyplot as plt
plt.plot(A, doppler_mesh)
