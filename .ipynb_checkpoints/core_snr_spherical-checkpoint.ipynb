# %% [markdown]
# ## 1. Doppler bandwidth

# %%
# broadside incidence angle
theta_i = 30
# antenna
la = 2  # m
wa = .3  # m
h = 500e3
wavel = 299792458.0 / 10e9

# %%
from spherical_earth_geometry_radar import *
import numpy as np

# create geometry
radarGeo = RadarGeometry()
# looking angle
beta = incidence_angle_to_looking_angle(theta_i * np.pi / 180)
radarGeo.set_rotation(beta, 0, 0)
# inital position
radarGeo.set_initial_position(0, 0, h)
# speed
v_s = radarGeo.orbital_speed()
radarGeo.set_speed(v_s)

print("orbital speed = ", v_s)
print("looking angle = ", beta * 180 / np.pi)
# Out:
# orbital speed =  [7612.68398988]
# looking angle =  27.620636562903183

# %%
Bd = nominal_doppler_bandwidth(la, theta_i, wavel, v_s, h)
print("Nominal Doppler Bandwidth = ", Bd)
# Out:
# Nominal Doppler Bandwidth =  [7613.29495281]

# %% [markdown]
# ## 2. incidence angle - Doppler axes

# %%
# example incidence angle extremes
theta_i_min = theta_i * np.pi / 180 - wavel / (2 * la)
theta_i_max = theta_i * np.pi / 180 + wavel / (2 * la)

incidence = np.linspace(theta_i_min, theta_i_max, 3)
doppler = np.linspace(-Bd / 2, Bd / 2, 5)

# %% [markdown]
# ## 3. Meshgridding and antenna pattern coordinates retrieval

# %%
# incidence doppler
I, D = np.meshgrid(incidence, doppler)
# incidence azimuth
I, A = mesh_doppler_to_azimuth(I, D, wavel, v_s, h)

# %%
print(I * 180 / np.pi)
# Out:
# [[29.57057894 30.         30.42942106]
#  [29.57057894 30.         30.42942106]
#  [29.57057894 30.         30.42942106]
#  [29.57057894 30.         30.42942106]
#  [29.57057894 30.         30.42942106]]

# %%
print(D)
# Out:
# [[-3806.6474764 -3806.6474764 -3806.6474764]
#  [-1903.3237382 -1903.3237382 -1903.3237382]
#  [    0.            0.            0.       ]
#  [ 1903.3237382  1903.3237382  1903.3237382]
#  [ 3806.6474764  3806.6474764  3806.6474764]]

# %%
print(A)
# Out:
# [[ 4259.73846636  4276.33802962  4293.28067483]
#  [ 2129.82067618  2138.12026727  2146.59139486]
#  [   -0.            -0.            -0.        ]
#  [-2129.82067618 -2138.12026727 -2146.59139486]
#  [-4259.73846636 -4276.33802962 -4293.28067483]]

# %%
# GCS
X, Y, Z = mesh_incidence_azimuth_to_gcs(I, A, wavel, v_s, h)

# %%
print(X)
# Out:
# [[ 4259.73814844  4276.33770796  4293.28034931]
#  [ 2129.82063644  2138.12022706  2146.59135418]
#  [   -0.            -0.            -0.        ]
#  [-2129.82063644 -2138.12022706 -2146.59135418]
#  [-4259.73814844 -4276.33770796 -4293.28034931]]

# %%
print(Y)
# Out:
# [[-260042.81917248 -264497.10438039 -268984.68313349]
#  [-260042.81917248 -264497.10438039 -268984.68313349]
#  [-260042.81917248 -264497.10438039 -268984.68313349]
#  [-260042.81917248 -264497.10438039 -268984.68313349]
#  [-260042.81917248 -264497.10438039 -268984.68313349]]

# %%
print(Z)
# Out:
# [[-5310.67465371 -5494.20747179 -5682.2696755 ]
#  [-5309.60570176 -5493.13014146 -5681.18375952]
#  [-5309.24940609 -5492.77105317 -5680.82180952]
#  [-5309.60570176 -5493.13014146 -5681.18375952]
#  [-5310.67465371 -5494.20747179 -5682.2696755 ]]

# %%
re=6371e3
R0_mesh = re * (np.sqrt(cos(I) ** 2 + 2 * h / re + h ** 2 / re ** 2) - cos(I))
# cosine of earth-centric elevation angle of azimuth circle parallel to the orbital plane on the sphere
cos_theta_e = (re + R0_mesh * cos(I)) / (re + h)

# %%
print(np.arccos(cos_theta_e) * 180 /np.pi)
# Out:
# [[2.3392711  2.37936344 2.41975662]
#  [2.3392711  2.37936344 2.41975662]
#  [2.3392711  2.37936344 2.41975662]
#  [2.3392711  2.37936344 2.41975662]
#  [2.3392711  2.37936344 2.41975662]]

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use('Qt5Agg')
# %matplotlib widget
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter(X,Y,Z)
ax.set_xlim(-5000,5000)
ax.set_ylim(-270e3,-250e3)
ax.set_zlim(-6e3,-5e3)

# draw sphere
u, v = np.mgrid[-2*np.pi/360:2*np.pi/360:2000j, 2.33* np.pi/180:2.43* np.pi/180:100j]
x = re * np.sin(u)*np.sin(v)
y = - re * np.cos(u)*np.sin(v)
z = re * np.cos(v) - re
ax.plot_surface(x, y, z, color="r", alpha =0.3)

ax.plot_wireframe(X,Y,Z)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
